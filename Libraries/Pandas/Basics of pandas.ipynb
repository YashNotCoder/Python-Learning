# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 4.5 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.8 MB 4.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.8 MB 4.9 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.8 MB 4.4 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.8 MB 4.9 MB/s eta 0:00:02
#    ------------------------- -------------- 6.3/9.8 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 5.8 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/4 [tzdata]
#    ---------------------------------------- 0/4 [tzdata]
#    -------------------- ------------------- 2/4 [python-dateutil]
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
# Dataframe

# %%
df = pd.DataFrame([11,22,33] , columns= ['col_name'])
print(df)
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
data = {
    'Name' : ['Mosh','Alex','Lily','Eren'] ,
    'Age'  : [21,15,17,22] ,
    'Salary' : [50000,30000,20000,60000],
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#    Name  Age  Salary
# 0  Mosh   21   50000
# 1  Alex   15   30000
# 2  Lily   17   20000
# 3  Eren   22   60000
