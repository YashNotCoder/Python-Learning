# %% [markdown]
# # Boolean variables

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Boolean logical operators

# %%
str = ("Hello World")

# %%
str.endswith("d")
# Out:
# True

# %%
str.isnumeric()
# Out:
# False

# %%
str.isalpha()
# Out:
# False

# %% [markdown]
# # LIST

# %%
type([])
# Out:
# list

# %%
my_list = ["apple" , "mango" , "orange"] 
print(my_list)
# Out:
# ['apple', 'mango', 'orange']

# %%
type(my_list)
# Out:
# list
