# %% [markdown]
# # Modules, Packages & Libraries in Python
# #### • What is Module
# #### • Create & Use a Module
# #### • What is Package
# #### • What is Library
# #### • Python pip
# #### • Most used Libraries

# %% [markdown]
# # Module is single python file (.py) containing python code

# %% [markdown]
# # Packages in Python
#
# A **package** is a collection of modules organized in directories (folders) with an `__init__.py` file. It allows you to structure your Python projects logically.
#
# ## Why Use Packages?
#
# - To group related modules together.
# - To create larger applications or libraries.
#
# ## Structure Example
#
# ```text
# my_package/
# │
# ├── __init__.py
# ├── math_utils.py
# └── string_utils.py

# %% [markdown]
# ![image.png](attachment:f0354188-6549-4389-a7a3-d4b7f05af3c7.png)
