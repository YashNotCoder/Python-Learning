# %% [markdown]
#  # Basics

# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %% [markdown]
# ## Type of data

# %%
type(10.00)
# Out:
# float

# %%
type(5)
# Out:
# int

# %% [markdown]
# ## Print

# %%
first_name='Yash'
last_name='Chandivade'

# %%
print("My first name is {} and last name is {}".format(first_name, last_name))
# Out:
# My first name is Yash and last name is Chandivade
