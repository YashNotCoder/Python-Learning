# %% [markdown]
# # Boolean variables

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Boolean logical operators

# %%
str = ("Hello World")

# %%
str.endswith("d")
# Out:
# True

# %%
str.isnumeric()
# Out:
# False

# %%
str.isalpha()
# Out:
# False

# %% [markdown]
# # LIST

# %%
type([])
# Out:
# list

# %%
my_list = ["apple" , "mango" , "orange"] 
print(my_list)
# Out:
# ['apple', 'mango', 'orange']

# %%
type(my_list)
# Out:
# list

# %%
len(my_list)
# Out:
# 3

# %% [markdown]
# # Append
#  ### The append() method adds an item to the end of a list.

# %%
my_list.append("banana")

# %%
my_list
# Out:
# ['apple', 'mango', 'orange', 'banana']

# %% [markdown]
# ## Indexing
# ### Indexing helps in finding the postion of the item in a list and also help to add or replace the item

# %%
my_list[1:]
# Out:
# ['mango', 'orange', 'banana']

# %%
my_list[2]
# Out:
# 'orange'

# %% [markdown]
# # Insert
