# %% [markdown]
# # Functions

# %% [markdown]
# #### Function without parameters

# %%
def my_func() :
    print("HELLO")

# %%
my_func()
# Out:
# HELLO

# %% [markdown]
# #### FUNCTION WITH PARAMETERS

# %%
def my_sum(a,b) :
    print(a + b)

# %% [markdown]
# my_sum(5,10)

# %%
def my_sum2(a,b) :
    result = a + b 
    print("YOur SUM is:",result)

# %%
my_sum2(8,9)
# Out:
# YOur SUM is: 17

# %% [markdown]
# ## Return Statement
# #### return is used to get the result as well as to preserve its datatype as in print function the data type becomes 'nonetype' , return is used to use the value later in the program

# %%
def sub(a,b) :
    return a - b

# %%
solv = sub(10,6)
print(solv) 
type(solv)
# Out:
# 4
# int

# %% [markdown]
# ## Pass Statement
# #### It is used to keep a function incomplete and can be modified later the next lines of code is executed , the function can be later completed

# %%
def newfunction() :
   pass 

print("HEllo")
# Out:
# HEllo

# %% [markdown]
# # Function Arguments
# #### 1) Required

# %%
def greetings(name):  # name is a parameter
   print("Hello, " + name + "!")

greetings("Madhav")  # Madhav as argument
# Out:
# Hello, Madhav!

# %% [markdown]
# ####  2) Default

# %%
def greetings(name = "World"): # default value
  print("Hello, " + name + "!")

greetings() # No argument passed
# Output: Hello, World!

greetings("Madhav") # Madhav as argument
# Output: Hello, Madhav!
# Out:
# Hello, World!
# Hello, Madhav!

# %% [markdown]
# #### 3) Keyword

# %%
def divide(a, b): # a,b are 2 parameters
 return a / b

result = divide(b=10, a=20) # with keyword arg
print(result) # Output: 2

result = divide(10, 20) # positional arg
print(result) # Output: 0.5
# Out:
# 2.0
# 0.5

# %% [markdown]
# ### 4) Arbitrary(IMP)

# %% [markdown]
# #### Arbitrary Positional Arguments (*args)
# #### If you're unsure how many arguments will be passed, use *args to accept any
# #### number of positional arguments.
# #### Purpose: Allows you to pass a variable number of positional arguments.
# #### Type: The arguments are stored as a tuple.
# #### Usage: Use when you want to pass multiple values that are accessed by position.

# %%
def add_numbers(*args):
 return sum(args)

# Any number of arguments
result = add_numbers(1, 2, 3, 4)
print(result) # Output: 10
# Out:
# 10

# %% [markdown]
# ## Arbitrary Keyword Arguments (**kwargs)
# #### If you want to pass a variable number of keyword arguments, use **kwargs.
# #### Purpose: Allows you to pass a variable number of keyword arguments
# #### (arguments with names).
# #### Type: The arguments are stored as a dictionary.
# #### Usage: Use when you want to pass multiple values that are accessed by name.

# %%
def print_details(**kwargs):
 for key, value in kwargs.items():
  print(f"{key}: {value}") 

print_details(name="Madhav", age=26)
# Out:
# name: Madhav
# age: 26
